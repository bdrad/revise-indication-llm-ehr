# %%
# !ls results/llm_balanced_test_dataset
# Out:
# mistralai_Ministral-8B-Instruct-2410.csv

# %%
import pandas as pd
# Out:
# /home/bdrad/miniconda3/envs/report_gen/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
# !ls results/llm_balanced_test_dataset
# Out:
# mistralai_Ministral-8B-Instruct-2410.csv
# mistralai_Mistral-7B-Instruct-v0.3.csv

# %%
pd.read_csv("results/llm_balanced_test_dataset/mistralai_Mistral-7B-Instruct-v0.3.csv")
# Out:
#   patientdurablekey                                  exam_type  \
# 0    D78BE72C516739            CT ABDOMEN/PELVIS WITH CONTRAST
# 1    DC91572E7BF19B         CT ABDOMEN/PELVIS WITHOUT CONTRAST
# 2    DFFBEDA925C6B2            CT ABDOMEN/PELVIS WITH CONTRAST
# 3    DC6C83AE0C757F            CT ABDOMEN/PELVIS WITH CONTRAST
# 4    DE149F6AD43201            CT ABDOMEN/PELVIS WITH CONTRAST
# 5    D99BC7229695D1  US ABDOMEN COMPLETE (RADIOLOGY PERFORMED)
# 6    DF6F2182084C17            CT ABDOMEN/PELVIS WITH CONTRAST
# 7    D3E047367ECD03            CT ABDOMEN/PELVIS WITH CONTRAST
# 8    DDC86BB99619FE                        US RENAL TRANSPLANT
# 9    D1339E95DAD977            CT ABDOMEN/PELVIS WITH CONTRAST
#
#        body_group imaging_modality report_deid_note_key  \
# 0  Abdomen/Pelvis               CT       D3E254FB4EBDC1
# 1  Abdomen/Pelvis               CT       D4150F90A708C3
# 2  Abdomen/Pelvis               CT       D265CA24A2B5FE
# ...
